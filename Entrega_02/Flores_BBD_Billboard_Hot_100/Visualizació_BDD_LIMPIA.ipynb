# %%
import pandas as pd
import altair as alt

df = pd.read_csv("BDD_Billboard_copia_Limpia_2000.csv", sep = ",")

df.head(16)
# Out:
#           date                      song  \
# 0   2000-01-05                    Smooth
# 1   2000-01-05               Back At One
# 2   2000-01-05  I Wanna Love You Forever
# 3   2000-01-05      My Love Is Your Love
# 4   2000-01-05                  Hot Boyz
# 5   2000-01-05        I Knew I Loved You
# 6   2000-01-05            Auld Lang Syne
# 7   2000-01-05            I Need To Know
# 8   2000-01-05        Bring It All To Me
# 9   2000-01-05          U Know What's Up
# 10  2000-01-05         What A Girl Wants
# 11  2000-01-05                Girl On TV
# 12  2000-01-05          Blue (Da Ba Dee)
# 13  2000-01-05                      24/7
# 14  2000-01-05           He Can't Love U
# 15  2000-01-05    Then The Morning Comes
#
#                                                artist  rank  last_week  \
# 0                        Santana Featuring Rob Thomas     1          1
# 1                                      Brian McKnight     2          2
# ...
